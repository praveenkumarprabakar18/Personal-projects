# %%
import pandas as pd
import numpy as np

# %%
customerDemographic=pd.read_csv("E:/KPMG Project/CustomerDemographic.csv")
customerDemographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0          1.0         Laraine  Medendorp  Female
# 1          2.0             Eli    Bockman    Male
# 2          3.0           Arlin     Dearle    Male
# 3          4.0          Talbot        NaN    Male
# 4          5.0  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                 93.0  1953-10-12     Executive Secretary
# 1                                 81.0  1980-12-16  Administrative Officer
# 2                                 61.0  1954-01-20      Recruiting Manager
# 3                                 33.0  1961-10-03                     NaN
# 4                                 56.0  1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  ...  \
# 0                Health      Mass Customer                  N  ...
# 1    Financial Services      Mass Customer                  N  ...
# ...

# %%
customerDemographic.drop(customerDemographic.columns[customerDemographic.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
customerDemographic
# Out:
#       customer_id      first_name  last_name  gender  \
# 0             1.0         Laraine  Medendorp  Female
# 1             2.0             Eli    Bockman    Male
# 2             3.0           Arlin     Dearle    Male
# 3             4.0          Talbot        NaN    Male
# 4             5.0  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3996       3997.0          Blanch     Nisuis  Female
# 3997       3998.0          Sarene    Woolley       U
# 3998       3999.0       Patrizius        NaN    Male
# 3999       4000.0           Kippy    Oldland    Male
# 4000          NaN             NaN        NaN     NaN
#
#       past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                   93.00  1953-10-12     Executive Secretary
# 1                                   81.00  1980-12-16  Administrative Officer
# 2                                   61.00  1954-01-20      Recruiting Manager
# ...

# %%
customerDemographic['job_title'].replace('', np.nan, inplace=True)

# %%
customerDemographic.dropna(subset=['job_title'], inplace=True)

# %%
customerDemographic
# Out:
#       customer_id      first_name  last_name  gender  \
# 0             1.0         Laraine  Medendorp  Female
# 1             2.0             Eli    Bockman    Male
# 2             3.0           Arlin     Dearle    Male
# 4             5.0  Sheila-kathryn     Calton  Female
# 7             8.0             Rod      Inder    Male
# ...           ...             ...        ...     ...
# 3994       3995.0           Rusty     Iapico    Male
# 3995       3996.0         Rosalia   Halgarth  Female
# 3996       3997.0          Blanch     Nisuis  Female
# 3997       3998.0          Sarene    Woolley       U
# 3999       4000.0           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                    93.0  1953-10-12     Executive Secretary
# 1                                    81.0  1980-12-16  Administrative Officer
# 2                                    61.0  1954-01-20      Recruiting Manager
# ...

# %%
cols=['job_industry_category', 'wealth_segment', 'DOB']

# %%
customerDemographic.dropna(axis = 0, subset = cols, how = 'any', inplace = True)

# %%
customerDemographic
# Out:
#       customer_id first_name  last_name  gender  \
# 0             1.0    Laraine  Medendorp  Female
# 1             2.0        Eli    Bockman    Male
# 2             3.0      Arlin     Dearle    Male
# 8             9.0       Mala       Lind  Female
# 9            10.0   Fiorenze    Birdall  Female
# ...           ...        ...        ...     ...
# 3992       3993.0       Andi    Dumelow  Female
# 3993       3994.0    Stephie      Byars  Female
# 3994       3995.0      Rusty     Iapico    Male
# 3995       3996.0    Rosalia   Halgarth  Female
# 3996       3997.0     Blanch     Nisuis  Female
#
#       past_3_years_bike_related_purchases         DOB  \
# 0                                    93.0  1953-10-12
# 1                                    81.0  1980-12-16
# 2                                    61.0  1954-01-20
# 8                                    97.0  1973-03-10
# 9                                    49.0  1988-10-11
# ...                                   ...         ...
# ...

# %%
customerDemographic['gender'].replace('U', 'Female', inplace=True)

# %%
customerDemographic
# Out:
#       customer_id first_name  last_name  gender  \
# 0             1.0    Laraine  Medendorp  Female
# 1             2.0        Eli    Bockman    Male
# 2             3.0      Arlin     Dearle    Male
# 8             9.0       Mala       Lind  Female
# 9            10.0   Fiorenze    Birdall  Female
# ...           ...        ...        ...     ...
# 3992       3993.0       Andi    Dumelow  Female
# 3993       3994.0    Stephie      Byars  Female
# 3994       3995.0      Rusty     Iapico    Male
# 3995       3996.0    Rosalia   Halgarth  Female
# 3996       3997.0     Blanch     Nisuis  Female
#
#       past_3_years_bike_related_purchases         DOB  \
# 0                                    93.0  1953-10-12
# 1                                    81.0  1980-12-16
# 2                                    61.0  1954-01-20
# 8                                    97.0  1973-03-10
# 9                                    49.0  1988-10-11
# ...                                   ...         ...
# ...

# %%
customerDemographic['gender'].value_counts()['Male']
# Out:
# 1382

# %%
customerDemographic['gender'].value_counts()['Female']
# Out:
# 1482

# %%
customerDemographic['past_3_years_bike_related_purchases'].value_counts()[0]
# Out:
# 30

# %%
purchases_mean= customerDemographic["past_3_years_bike_related_purchases"].mean()

# %%
customerDemographic['past_3_years_bike_related_purchases'].replace(0, purchases_mean , inplace=True)

# %%
customerDemographic
# Out:
#       customer_id first_name  last_name  gender  \
# 0             1.0    Laraine  Medendorp  Female
# 1             2.0        Eli    Bockman    Male
# 2             3.0      Arlin     Dearle    Male
# 8             9.0       Mala       Lind  Female
# 9            10.0   Fiorenze    Birdall  Female
# ...           ...        ...        ...     ...
# 3992       3993.0       Andi    Dumelow  Female
# 3993       3994.0    Stephie      Byars  Female
# 3994       3995.0      Rusty     Iapico    Male
# 3995       3996.0    Rosalia   Halgarth  Female
# 3996       3997.0     Blanch     Nisuis  Female
#
#       past_3_years_bike_related_purchases         DOB  \
# 0                                    93.0  1953-10-12
# 1                                    81.0  1980-12-16
# 2                                    61.0  1954-01-20
# 8                                    97.0  1973-03-10
# 9                                    49.0  1988-10-11
# ...                                   ...         ...
# ...

# %%
customerDemographic['deceased_indicator'].value_counts()['N']
# Out:
# 2863

# %%
customerDemographic['deceased_indicator'].value_counts()['Y']
# Out:
# 2

# %%
customerDemographic['deceased_indicator'].replace(' ', 'N', inplace=True)

# %%
customerDemographic.drop(customerDemographic[customerDemographic['DOB'] == "1843-12-21"].index, inplace = True)

# %%
customerDemographic
# Out:
#       customer_id first_name  last_name  gender  \
# 0             1.0    Laraine  Medendorp  Female
# 1             2.0        Eli    Bockman    Male
# 2             3.0      Arlin     Dearle    Male
# 8             9.0       Mala       Lind  Female
# 9            10.0   Fiorenze    Birdall  Female
# ...           ...        ...        ...     ...
# 3992       3993.0       Andi    Dumelow  Female
# 3993       3994.0    Stephie      Byars  Female
# 3994       3995.0      Rusty     Iapico    Male
# 3995       3996.0    Rosalia   Halgarth  Female
# 3996       3997.0     Blanch     Nisuis  Female
#
#       past_3_years_bike_related_purchases         DOB  \
# 0                                    93.0  1953-10-12
# 1                                    81.0  1980-12-16
# 2                                    61.0  1954-01-20
# 8                                    97.0  1973-03-10
# 9                                    49.0  1988-10-11
# ...                                   ...         ...
# ...

# %%
customerDemographic.to_csv('E:/KPMG Project/Cleaned_customerDemographic.csv', header=True, index=False)

# %%
customerAddress=pd.read_csv("E:/KPMG Project/CustomerAddress.csv")

# %%
customerAddress
# Out:
#       customer_id                    address  postcode            state  \
# 0               1         060 Morning Avenue      2016  New South Wales
# 1               2        6 Meadow Vale Court      2153  New South Wales
# 2               4         0 Holy Cross Court      4211              QLD
# 3               5        17979 Del Mar Point      2448  New South Wales
# 4               6           9 Oakridge Court      3216              VIC
# ...           ...                        ...       ...              ...
# 3994         3999            1482 Hauk Trail      3064              VIC
# 3995         4000  57042 Village Green Point      4511              QLD
# 3996         4001     87 Crescent Oaks Alley      2756              NSW
# 3997         4002           8194 Lien Street      4032              QLD
# 3998         4003            320 Acker Drive      2251              NSW
#
#         country  property_valuation
# 0     Australia                  10
# ...

# %%
customerAddress['property_valuation'].dtypes
# Out:
# dtype('int64')

# %%
column=customerAddress['property_valuation']

# %%
count = column[column == 0].count()
count
# Out:
# 0

# %%
customerAddress['country']
# Out:
# 0       Australia
# 1       Australia
# 2       Australia
# 3       Australia
# 4       Australia
#           ...
# 3994    Australia
# 3995    Australia
# 3996    Australia
# 3997    Australia
# 3998    Australia
# Name: country, Length: 3999, dtype: object

# %%
customerAddress['country'].value_counts()
# Out:
# Australia    3999
# Name: country, dtype: int64

# %%
customerAddress['state'].value_counts()
# Out:
# NSW                2054
# VIC                 939
# QLD                 838
# New South Wales      86
# Victoria             82
# Name: state, dtype: int64

# %%
customerAddress.to_csv('E:/KPMG Project/Cleaned_customerAddress.csv', header=True, index=False)

# %%
import pandas as pd
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
Transactions=pd.read_csv("E:/KPMG Project/Transactions.csv", header=None)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3325: DtypeWarning: Columns (0,1,2,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
Transactions
# Out:
#                                                      0           1    \
# 0      Note: The data and information in this documen...         NaN
# 1                                         transaction_id  product_id
# 2                                                      1           2
# 3                                                      2           3
# 4                                                      3          37
# ...                                                  ...         ...
# 19997                                              19996          51
# 19998                                              19997          41
# 19999                                              19998          87
# 20000                                              19999           6
# 20001                                              20000          11
#
#                2                 3             4             5    \
# 0              NaN               NaN           NaN           NaN
# ...

# %%
Transactions.drop([0], inplace=True)

# %%
Transactions=Transactions[1:]

# %%
Transactions
# Out:
# 1      transaction_id  product_id  customer_id  transaction_date  \
# 1      transaction_id  product_id  customer_id  transaction_date
# 2                   1           2         2950        25-02-2017
# 3                   2           3         3120        21-05-2017
# 4                   3          37          402        16-10-2017
# 5                   4          88         3135        31-08-2017
# ...               ...         ...          ...               ...
# 19997           19996          51         1018        24-06-2017
# 19998           19997          41          127        09-11-2017
# 19999           19998          87         2284        14-04-2017
# 20000           19999           6         2764        03-07-2017
# 20001           20000          11         1144        22-09-2017
#
# 1      online_order  order_status           brand  product_line  \
# 1      online_order  order_status           brand  product_line
# ...

# %%
Transactions.columns=Transactions.iloc[0]

# %%
Transactions.drop([1])
# Out:
# 1     transaction_id product_id customer_id transaction_date online_order  \
# 2                  1          2        2950       25-02-2017        FALSE
# 3                  2          3        3120       21-05-2017         TRUE
# 4                  3         37         402       16-10-2017        FALSE
# 5                  4         88        3135       31-08-2017        FALSE
# 6                  5         78         787       01-10-2017         TRUE
# ...              ...        ...         ...              ...          ...
# 19997          19996         51        1018       24-06-2017         True
# 19998          19997         41         127       09-11-2017         True
# 19999          19998         87        2284       14-04-2017         True
# 20000          19999          6        2764       03-07-2017        False
# 20001          20000         11        1144       22-09-2017         True
#
# 1     order_status           brand product_line product_class product_size  \
# ...

# %%
Transactions.reset_index(drop=True, inplace=True)

# %%
Transactions
# Out:
# 1      transaction_id  product_id  customer_id  transaction_date  \
# 0      transaction_id  product_id  customer_id  transaction_date
# 1                   1           2         2950        25-02-2017
# 2                   2           3         3120        21-05-2017
# 3                   3          37          402        16-10-2017
# 4                   4          88         3135        31-08-2017
# ...               ...         ...          ...               ...
# 19996           19996          51         1018        24-06-2017
# 19997           19997          41          127        09-11-2017
# 19998           19998          87         2284        14-04-2017
# 19999           19999           6         2764        03-07-2017
# 20000           20000          11         1144        22-09-2017
#
# 1      online_order  order_status           brand  product_line  \
# 0      online_order  order_status           brand  product_line
# ...

# %%
Transactions.drop([0])
# Out:
# 1      index transaction_id product_id customer_id transaction_date  \
# 1          1              1          2        2950       25-02-2017
# 2          2              2          3        3120       21-05-2017
# 3          3              3         37         402       16-10-2017
# 4          4              4         88        3135       31-08-2017
# 5          5              5         78         787       01-10-2017
# ...      ...            ...        ...         ...              ...
# 19996  19996          19996         51        1018       24-06-2017
# 19997  19997          19997         41         127       09-11-2017
# 19998  19998          19998         87        2284       14-04-2017
# 19999  19999          19999          6        2764       03-07-2017
# 20000  20000          20000         11        1144       22-09-2017
#
# 1     online_order order_status           brand product_line product_class  \
# ...

# %%
Transactions
# Out:
# 1      index  transaction_id  product_id  customer_id  transaction_date  \
# 0          0  transaction_id  product_id  customer_id  transaction_date
# 1          1               1           2         2950        25-02-2017
# 2          2               2           3         3120        21-05-2017
# 3          3               3          37          402        16-10-2017
# 4          4               4          88         3135        31-08-2017
# ...      ...             ...         ...          ...               ...
# 19996  19996           19996          51         1018        24-06-2017
# 19997  19997           19997          41          127        09-11-2017
# 19998  19998           19998          87         2284        14-04-2017
# 19999  19999           19999           6         2764        03-07-2017
# 20000  20000           20000          11         1144        22-09-2017
#
# 1      online_order  order_status           brand  product_line  \
# ...

# %%
Transactions.drop([0])
# Out:
# 1      index transaction_id product_id customer_id transaction_date  \
# 1          1              1          2        2950       25-02-2017
# 2          2              2          3        3120       21-05-2017
# 3          3              3         37         402       16-10-2017
# 4          4              4         88        3135       31-08-2017
# 5          5              5         78         787       01-10-2017
# ...      ...            ...        ...         ...              ...
# 19996  19996          19996         51        1018       24-06-2017
# 19997  19997          19997         41         127       09-11-2017
# 19998  19998          19998         87        2284       14-04-2017
# 19999  19999          19999          6        2764       03-07-2017
# 20000  20000          20000         11        1144       22-09-2017
#
# 1     online_order order_status           brand product_line product_class  \
# ...

# %%
Transactions.dropna(axis=1,how='all',inplace=True)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
Transactions
# Out:
# 1      index  transaction_id  product_id  customer_id  transaction_date  \
# 0          0  transaction_id  product_id  customer_id  transaction_date
# 1          1               1           2         2950        25-02-2017
# 2          2               2           3         3120        21-05-2017
# 3          3               3          37          402        16-10-2017
# 4          4               4          88         3135        31-08-2017
# ...      ...             ...         ...          ...               ...
# 19996  19996           19996          51         1018        24-06-2017
# 19997  19997           19997          41          127        09-11-2017
# 19998  19998           19998          87         2284        14-04-2017
# 19999  19999           19999           6         2764        03-07-2017
# 20000  20000           20000          11         1144        22-09-2017
#
# 1      online_order  order_status           brand  product_line  \
# ...

# %%
Transactions.drop([0], inplace=True)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
Transactions
# Out:
# 1      index transaction_id product_id customer_id transaction_date  \
# 1          1              1          2        2950       25-02-2017
# 2          2              2          3        3120       21-05-2017
# 3          3              3         37         402       16-10-2017
# 4          4              4         88        3135       31-08-2017
# 5          5              5         78         787       01-10-2017
# ...      ...            ...        ...         ...              ...
# 19996  19996          19996         51        1018       24-06-2017
# 19997  19997          19997         41         127       09-11-2017
# 19998  19998          19998         87        2284       14-04-2017
# 19999  19999          19999          6        2764       03-07-2017
# 20000  20000          20000         11        1144       22-09-2017
#
# 1     online_order order_status           brand product_line product_class  \
# ...

# %%
Transactions.dropna(axis = 0, subset = ['transaction_id', 'product_id', 'customer_id', 'transaction_date', 'online_order', 'order_status', 'brand', 'product_line', 'product_class', 'product_size', 'list_price', 'standard_cost', 'product_first_sold_date'], how = 'any', inplace = True)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
Transactions
# Out:
# 1      index transaction_id product_id customer_id transaction_date  \
# 1          1              1          2        2950       25-02-2017
# 2          2              2          3        3120       21-05-2017
# 3          3              3         37         402       16-10-2017
# 4          4              4         88        3135       31-08-2017
# 5          5              5         78         787       01-10-2017
# ...      ...            ...        ...         ...              ...
# 19996  19996          19996         51        1018       24-06-2017
# 19997  19997          19997         41         127       09-11-2017
# 19998  19998          19998         87        2284       14-04-2017
# 19999  19999          19999          6        2764       03-07-2017
# 20000  20000          20000         11        1144       22-09-2017
#
# 1     online_order order_status           brand product_line product_class  \
# ...

# %%
Transactions.to_csv('E:/KPMG Project/Cleaned_Transactions.csv', header=True, index=False)

# %%
cd=pd.read_csv('E:/KPMG Project/Cleaned_customerDemographic.csv')

# %%
ca=pd.read_csv('E:/KPMG Project/Cleaned_customerAddress.csv')

# %%
ca
# Out:
#       customer_id                    address  postcode            state  \
# 0               1         060 Morning Avenue      2016  New South Wales
# 1               2        6 Meadow Vale Court      2153  New South Wales
# 2               4         0 Holy Cross Court      4211              QLD
# 3               5        17979 Del Mar Point      2448  New South Wales
# 4               6           9 Oakridge Court      3216              VIC
# ...           ...                        ...       ...              ...
# 3994         3999            1482 Hauk Trail      3064              VIC
# 3995         4000  57042 Village Green Point      4511              QLD
# 3996         4001     87 Crescent Oaks Alley      2756              NSW
# 3997         4002           8194 Lien Street      4032              QLD
# 3998         4003            320 Acker Drive      2251              NSW
#
#         country  property_valuation
# 0     Australia                  10
# ...

# %%
cd.dtypes
# Out:
# customer_id                            float64
# first_name                              object
# last_name                               object
# gender                                  object
# past_3_years_bike_related_purchases    float64
# DOB                                     object
# job_title                               object
# job_industry_category                   object
# wealth_segment                          object
# deceased_indicator                      object
# owns_car                                object
# tenure                                 float64
# dtype: object

# %%
cd[['customer_id']] = cd[['customer_id']].astype(int)

# %%
cd
# Out:
#       customer_id first_name  last_name  gender  \
# 0               1    Laraine  Medendorp  Female
# 1               2        Eli    Bockman    Male
# 2               3      Arlin     Dearle    Male
# 3               9       Mala       Lind  Female
# 4              10   Fiorenze    Birdall  Female
# ...           ...        ...        ...     ...
# 2859         3993       Andi    Dumelow  Female
# 2860         3994    Stephie      Byars  Female
# 2861         3995      Rusty     Iapico    Male
# 2862         3996    Rosalia   Halgarth  Female
# 2863         3997     Blanch     Nisuis  Female
#
#       past_3_years_bike_related_purchases         DOB  \
# 0                                    93.0  1953-10-12
# 1                                    81.0  1980-12-16
# 2                                    61.0  1954-01-20
# 3                                    97.0  1973-03-10
# 4                                    49.0  1988-10-11
# ...                                   ...         ...
# ...

# %%
merged_data =cd.merge(ca,how ='left').merge(Transactions,how ='left')

# %%
merged_data
# Out:
#       customer_id first_name  last_name  gender  \
# 0               1    Laraine  Medendorp  Female
# 1               1    Laraine  Medendorp  Female
# 2               1    Laraine  Medendorp  Female
# 3               1    Laraine  Medendorp  Female
# 4               1    Laraine  Medendorp  Female
# ...           ...        ...        ...     ...
# 12989        3993       Andi    Dumelow  Female
# 12990        3994    Stephie      Byars  Female
# 12991        3995      Rusty     Iapico    Male
# 12992        3996    Rosalia   Halgarth  Female
# 12993        3997     Blanch     Nisuis  Female
#
#        past_3_years_bike_related_purchases         DOB  \
# 0                                     93.0  1953-10-12
# 1                                     93.0  1953-10-12
# 2                                     93.0  1953-10-12
# 3                                     93.0  1953-10-12
# 4                                     93.0  1953-10-12
# ...

# %%
merged_data.dropna(axis = 0, how = 'any', inplace = True)

# %%
merged_data
# Out:
#       customer_id first_name  last_name  gender  \
# 0               1    Laraine  Medendorp  Female
# 1               1    Laraine  Medendorp  Female
# 2               1    Laraine  Medendorp  Female
# 3               1    Laraine  Medendorp  Female
# 4               1    Laraine  Medendorp  Female
# ...           ...        ...        ...     ...
# 12655        3496      Danya   Burnyeat    Male
# 12656        3496      Danya   Burnyeat    Male
# 12657        3497       Thia      O'Day  Female
# 12658        3497       Thia      O'Day  Female
# 12659        3497       Thia      O'Day  Female
#
#        past_3_years_bike_related_purchases         DOB  \
# 0                                     93.0  1953-10-12
# 1                                     93.0  1953-10-12
# 2                                     93.0  1953-10-12
# 3                                     93.0  1953-10-12
# 4                                     93.0  1953-10-12
# ...

# %%
merged_data.to_csv("E:/KPMG Project/merged_data.csv", header=True, index=False)

# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
merged=pd.read_csv("E:/KPMG Project/merged_data.csv")
merged
# Out:
#        customer_id first_name  last_name  gender  \
# 0                1    Laraine  Medendorp  Female
# 1                1    Laraine  Medendorp  Female
# 2                1    Laraine  Medendorp  Female
# 3                1    Laraine  Medendorp  Female
# 4                1    Laraine  Medendorp  Female
# ...            ...        ...        ...     ...
# 12241         3496      Danya   Burnyeat    Male
# 12242         3496      Danya   Burnyeat    Male
# 12243         3497       Thia      O'Day  Female
# 12244         3497       Thia      O'Day  Female
# 12245         3497       Thia      O'Day  Female
#
#        past_3_years_bike_related_purchases         DOB  \
# 0                                     93.0  1953-10-12
# 1                                     93.0  1953-10-12
# 2                                     93.0  1953-10-12
# 3                                     93.0  1953-10-12
# 4                                     93.0  1953-10-12
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-dfb6e2e48ead> in <module>
# ----> 1 merged['past_3_years_bike_related_purchases'].summary()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
merged['past_3_years_bike_related_purchases']
# Out:
# 0        93.0
# 1        93.0
# 2        93.0
# 3        93.0
# 4        93.0
#          ...
# 12241    99.0
# 12242    99.0
# 12243    73.0
# 12244    73.0
# 12245    73.0
# Name: past_3_years_bike_related_purchases, Length: 12246, dtype: float64

# %%
merged['customer_id'].mean()
# Out:
# 49.99862547274746

# %%
print()
# Out:
# [False False False ... False False False]

# %%
merged.query('customer_id==428')
# Out:
#       customer_id first_name last_name  gender  \
# 1636          428     Freida    Everil  Female
# 1637          428     Freida    Everil  Female
# 1638          428     Freida    Everil  Female
# 1639          428     Freida    Everil  Female
# 1640          428     Freida    Everil  Female
# 1641          428     Freida    Everil  Female
# 1642          428     Freida    Everil  Female
# 1643          428     Freida    Everil  Female
#
#       past_3_years_bike_related_purchases         DOB            job_title  \
# 1636                            49.497382  1977-05-03  Structural Engineer
# 1637                            49.497382  1977-05-03  Structural Engineer
# 1638                            49.497382  1977-05-03  Structural Engineer
# 1639                            49.497382  1977-05-03  Structural Engineer
# 1640                            49.497382  1977-05-03  Structural Engineer
# 1641                            49.497382  1977-05-03  Structural Engineer
# ...

# %%
merged.to_csv("E:/KPMG Project/merged_data.csv", header=True, index=False)

# %%
merged['past_3_years_bike_related_purchases']=merged['past_3_years_bike_related_purchases'].round(decimals=3)

# %%
merged.query('customer_id==428')
# Out:
#       customer_id first_name last_name  gender  \
# 1636          428     Freida    Everil  Female
# 1637          428     Freida    Everil  Female
# 1638          428     Freida    Everil  Female
# 1639          428     Freida    Everil  Female
# 1640          428     Freida    Everil  Female
# 1641          428     Freida    Everil  Female
# 1642          428     Freida    Everil  Female
# 1643          428     Freida    Everil  Female
#
#       past_3_years_bike_related_purchases         DOB            job_title  \
# 1636                                  0.0  1977-05-03  Structural Engineer
# 1637                                  0.0  1977-05-03  Structural Engineer
# 1638                                  0.0  1977-05-03  Structural Engineer
# 1639                                  0.0  1977-05-03  Structural Engineer
# 1640                                  0.0  1977-05-03  Structural Engineer
# 1641                                  0.0  1977-05-03  Structural Engineer
# ...

# %%
merged['past_3_years_bike_related_purchases'].replace(49.497, 0.00, inplace=True)

# %%
# Out:
# product_line       Mountain  Road  Standard  Touring
# wealth_segment
# Affluent Customer        56   592      2206      186
# High Net Worth           63   614      2243      186
# Mass Customer           130  1253      4359      358

# %%
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF8EF2D940>,
# ...
#       dtype=object)

# %%
# Out:
# brand                  Giant Bicycles  Norco Bicycles  OHM Cycles  Solex  \
# job_industry_category
# Argiculture                        73              64          61    106
# Entertainment                      93              73          69    109
# Financial Services                490             423         460    602
# Health                            377             402         348    519
# IT                                 72              74          81    114
# Manufacturing                     510             420         460    669
# Property                          158             136         171    220
# Retail                            214             180         191    261
# Telecommunications                 45              36          42     58
#
# brand                  Trek Bicycles  WeareA2B
# job_industry_category
# Argiculture                       62        66
# Entertainment                     84        84
# Financial Services               453       514
# ...

# %%
# Out:
# brand              Giant Bicycles  Norco Bicycles  OHM Cycles  Solex  \
# wealth_segment
# Affluent Customer             520             428         466    651
# High Net Worth                519             479         471    673
# Mass Customer                 993             901         946   1334
#
# brand              Trek Bicycles  WeareA2B
# wealth_segment
# Affluent Customer            484       491
# High Net Worth               450       514
# Mass Customer                931       995

# %%
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'index', 'transaction_id', 'product_id',
#        'transaction_date', 'online_order', 'order_status', 'brand',
#        'product_line', 'product_class', 'product_size', 'list_price',
#        'standard_cost', 'product_first_sold_date'],
#       dtype='object')

# %%
import pandas as pd
newcustomer=pd.read_csv("E:/KPMG Project/NewCustomerlist.csv")
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
newcustomer
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#             DOB                     job_title job_industry_category  \
# ...

# %%
newcustomer.drop(newcustomer.columns[newcustomer.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
cols=['job_industry_category', 'wealth_segment', 'DOB']
newcustomer.dropna(axis = 0, subset = cols, how = 'any', inplace = True)
newcustomer
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#             DOB                     job_title job_industry_category  \
# ...
