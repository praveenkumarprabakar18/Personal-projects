# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
train=pd.read_csv("https://raw.githubusercontent.com/praveenkumarprabakar18/Personal-projects/main/perslogproj/train.csv")
train
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
test=pd.read_csv("https://raw.githubusercontent.com/praveenkumarprabakar18/Personal-projects/main/perslogproj/test.csv")
test
# Out:
#        Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0               0  19556  Female     Loyal Customer   52  Business travel
# 1               1  90035  Female     Loyal Customer   36  Business travel
# 2               2  12360    Male  disloyal Customer   20  Business travel
# 3               3  77959    Male     Loyal Customer   44  Business travel
# 4               4  36875  Female     Loyal Customer   49  Business travel
# ...           ...    ...     ...                ...  ...              ...
# 25971       25971  78463    Male  disloyal Customer   34  Business travel
# 25972       25972  71167    Male     Loyal Customer   23  Business travel
# 25973       25973  37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974  90086    Male     Loyal Customer   14  Business travel
# 25975       25975  34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# ...

# %%
complete=[train,test]
data=pd.concat(complete)
data
# Out:
#        Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0               0   70172    Male     Loyal Customer   13  Personal Travel
# 1               1    5047    Male  disloyal Customer   25  Business travel
# 2               2  110028  Female     Loyal Customer   26  Business travel
# 3               3   24026  Female     Loyal Customer   25  Business travel
# 4               4  119299    Male     Loyal Customer   61  Business travel
# ...           ...     ...     ...                ...  ...              ...
# 25971       25971   78463    Male  disloyal Customer   34  Business travel
# 25972       25972   71167    Male     Loyal Customer   23  Business travel
# 25973       25973   37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974   90086    Male     Loyal Customer   14  Business travel
# 25975       25975   34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# ...

# %%
data.drop(data.columns[data.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
data
# Out:
#            id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0       70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1        5047    Male  disloyal Customer   25  Business travel  Business
# 2      110028  Female     Loyal Customer   26  Business travel  Business
# 3       24026  Female     Loyal Customer   25  Business travel  Business
# 4      119299    Male     Loyal Customer   61  Business travel  Business
# ...       ...     ...                ...  ...              ...       ...
# 25971   78463    Male  disloyal Customer   34  Business travel  Business
# 25972   71167    Male     Loyal Customer   23  Business travel  Business
# 25973   37675  Female     Loyal Customer   17  Personal Travel       Eco
# 25974   90086    Male     Loyal Customer   14  Business travel  Business
# 25975   34799  Female     Loyal Customer   42  Personal Travel       Eco
#
#        Flight Distance  Inflight wifi service  \
# ...

# %%
data.drop(['id'], axis=1, inplace=True)
data.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
data['Customer Type'].value_counts()
# Out:
# Loyal Customer       106100
# disloyal Customer     23780
# Name: Customer Type, dtype: int64

# %%
data['Type of Travel'].value_counts()
# Out:
# Business travel    89693
# Personal Travel    40187
# Name: Type of Travel, dtype: int64

# %%
data['Class'].value_counts()
# Out:
# Business    62160
# Eco         58309
# Eco Plus     9411
# Name: Class, dtype: int64

# %%
data['satisfaction'].value_counts()
# Out:
# neutral or dissatisfied    73452
# satisfied                  56428
# Name: satisfaction, dtype: int64

# %%
def cust_type_transform(x):
    if x=='Loyal Customer':
        return 0
    elif x=='disloyal Customer':
        return 1
    else:
        return -1
    
def gender_transform(x):
    if x=="Female":
        return 0
    elif x=="Male":
        return 1
def travel_type_transform(x):
    if x=="Business travel":
        return 0
    elif x=="Personal Travel":
        return 1
    else:
        return -1
def Class_transform(x):
    if x=="Business":
        return 0
    elif x=="Eco":
        return 1
    elif x=="Eco Plus":
        return 2
    else:
        return -1
def satisfaction_transform(x):
    if x=="neutral or dissatisfied":
        return 0
    elif x=="satisfied":
        return 1
    else:
        return -1
    
data['Gender']=data['Gender'].apply(gender_transform)
data['Customer Type']=data['Customer Type'].apply(cust_type_transform)

# %%
data['Type of Travel']=data["Type of Travel"].apply(travel_type_transform)
data['Class']=data['Class'].apply(Class_transform)
data['satisfaction']=data['satisfaction'].apply(satisfaction_transform)

# %%
data.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              0   13               1      2              460
# 1       1              1   25               0      0              235
# 2       0              0   26               0      0             1142
# 3       0              0   25               0      0              562
# 4       1              0   61               0      0              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# ...

# %%
data['Arrival Delay in Minutes'].median()
data['Arrival Delay in Minutes'].fillna(data['Arrival Delay in Minutes'].median())
# Out:
# 0        18.0
# 1         6.0
# 2         0.0
# 3         9.0
# 4         0.0
#          ...
# 25971     0.0
# 25972     0.0
# 25973     0.0
# 25974     0.0
# 25975     0.0
# Name: Arrival Delay in Minutes, Length: 129880, dtype: float64

# %%
data.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              0   13               1      2              460
# 1       1              1   25               0      0              235
# 2       0              0   26               0      0             1142
# 3       0              0   25               0      0              562
# 4       1              0   61               0      0              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# ...

# %%
correlation=data.corr(method="spearman")
mask=np.zeros_like(correlation,dtype=np.bool)
plt.figure(figsize=(20,18))
s=sns.heatmap(correlation, annot=True, mask=mask, cmap='RdBu', vmin=-1,vmax=1, center=0, square=True, linewidth=0.5)
s.set_yticklabels(s.get_yticklabels(), rotation=0,fontsize=12)
s.set_xticklabels(s.get_xticklabels(), rotation=90, fontsize=12)
plt.title("Correlation Heat Map")
plt.show()
# Out:
# <ipython-input-24-c9a03090a056>:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.zeros_like(correlation,dtype=np.bool)

# %%
c_data=data[np.isfinite(data).all(1)]
c_data
# Out:
#        Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0           1              0   13               1      2              460
# 1           1              1   25               0      0              235
# 2           0              0   26               0      0             1142
# 3           0              0   25               0      0              562
# 4           1              0   61               0      0              214
# ...       ...            ...  ...             ...    ...              ...
# 25971       1              1   34               0      0              526
# 25972       1              0   23               0      0              646
# 25973       0              0   17               1      1              828
# 25974       1              0   14               0      0             1127
# 25975       0              0   42               1      1              264
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# ...

# %%
c_data.dtypes
# Out:
# Gender                                 int64
# Customer Type                          int64
# Age                                    int64
# Type of Travel                         int64
# Class                                  int64
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# ...

# %%
x=c_data.loc[:,c_data.columns!='satisfaction']
y=c_data.loc[:,c_data.columns=='satisfaction']
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.4, random_state=0)

# %%
x
# Out:
#        Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0           1              0   13               1      2              460
# 1           1              1   25               0      0              235
# 2           0              0   26               0      0             1142
# 3           0              0   25               0      0              562
# 4           1              0   61               0      0              214
# ...       ...            ...  ...             ...    ...              ...
# 25971       1              1   34               0      0              526
# 25972       1              0   23               0      0              646
# 25973       0              0   17               1      1              828
# 25974       1              0   14               0      0             1127
# 25975       0              0   42               1      1              264
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# ...

# %%
y_test
# Out:
#        satisfaction
# 43170             1
# 21338             1
# 28463             1
# 20300             0
# 39398             0
# ...             ...
# 62855             0
# 50169             0
# 12135             0
# 73414             1
# 25002             0
#
# [38847 rows x 1 columns]

# %%
steps=[('Scaling', StandardScaler()), ('Reducing_dimension', PCA(n_components=0.85)), ('Modelling', LogisticRegression())]
pipeline=Pipeline(steps)
pipeline.fit(x_train,np.ravel(y_train))
y_pred=pipeline.predict(x_test)
acc=metrics.accuracy_score(y_true=y_test, y_pred=y_pred)
c_matrix=metrics.confusion_matrix(y_true=y_test, y_pred=y_pred)
print("Accuracy is", acc)
print(c_matrix)
# Out:
# Accuracy is 0.8501785886668597
# [[25984  3403]
#  [ 4357 18051]]

# %%
cmd=ConfusionMatrixDisplay(c_matrix, display_labels=['Satisfaction=0','Satisfaction=1'])
cmd.plot()

# %%
precision=round(metrics.precision_score(y_true=y_test, y_pred=y_pred)*100,2)
recall=round(metrics.recall_score(y_true=y_test, y_pred=y_pred)*100,2)
print("Precision is ", precision)
print("Recall is", recall)
# Out:
# Precision is  84.14
# Recall is 80.56
