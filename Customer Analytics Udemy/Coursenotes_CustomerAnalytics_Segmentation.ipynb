# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenkumarprabakar18/Classnotes/blob/main/Coursenotes_CustomerAnalytics_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
sns.set()
import pickle

# %%
segment_data=pd.read_csv("https://raw.githubusercontent.com/praveenkumarprabakar18/firstrepo/main/segmentation%20data.csv")
segment_data.head()
# Out:
#           ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0  100000001    0               0   67          2  124670           1
# 1  100000002    1               1   22          1  150773           1
# 2  100000003    0               0   49          1   89210           0
# 3  100000004    0               0   45          1  171565           1
# 4  100000005    0               0   53          1  149031           1
#
#    Settlement size
# 0                2
# 1                2
# 2                0
# 3                1
# 4                1

# %% [markdown]
# segment_data.describe()

# %%
segment_data.describe()
# Out:
#                  ID          Sex  Marital status          Age   Education  \
# count  2.000000e+03  2000.000000     2000.000000  2000.000000  2000.00000
# mean   1.000010e+08     0.457000        0.496500    35.909000     1.03800
# std    5.774946e+02     0.498272        0.500113    11.719402     0.59978
# min    1.000000e+08     0.000000        0.000000    18.000000     0.00000
# 25%    1.000005e+08     0.000000        0.000000    27.000000     1.00000
# 50%    1.000010e+08     0.000000        0.000000    33.000000     1.00000
# 75%    1.000015e+08     1.000000        1.000000    42.000000     1.00000
# max    1.000020e+08     1.000000        1.000000    76.000000     3.00000
#
#               Income   Occupation  Settlement size
# count    2000.000000  2000.000000      2000.000000
# mean   120954.419000     0.810500         0.739000
# std     38108.824679     0.638587         0.812533
# min     35832.000000     0.000000         0.000000
# 25%     97663.250000     0.000000         0.000000
# 50%    115548.500000     1.000000         1.000000
# 75%    138072.250000     1.000000         1.000000
# max    309364.000000     2.000000         2.000000

# %%
segment_data.corr()
# Out:
#                        ID       Sex  Marital status       Age  Education  \
# ID               1.000000  0.328262        0.074403 -0.085246   0.012543
# Sex              0.328262  1.000000        0.566511 -0.182885   0.244838
# Marital status   0.074403  0.566511        1.000000 -0.213178   0.374017
# Age             -0.085246 -0.182885       -0.213178  1.000000   0.654605
# Education        0.012543  0.244838        0.374017  0.654605   1.000000
# Income          -0.303217 -0.195146       -0.073528  0.340610   0.233459
# Occupation      -0.291958 -0.202491       -0.029490  0.108388   0.064524
# Settlement size -0.378445 -0.300803       -0.097041  0.119751   0.034732
#
#                    Income  Occupation  Settlement size
# ID              -0.303217   -0.291958        -0.378445
# Sex             -0.195146   -0.202491        -0.300803
# Marital status  -0.073528   -0.029490        -0.097041
# Age              0.340610    0.108388         0.119751
# Education        0.233459    0.064524         0.034732
# Income           1.000000    0.680357         0.490881
# Occupation       0.680357    1.000000         0.571795
# Settlement size  0.490881    0.571795         1.000000

# %%
plt.figure(figsize=(12,9))
s=sns.heatmap(segment_data.corr(), annot=True, cmap='RdBu', vmin=-1, vmax=1)
s.set_yticklabels(s.get_yticklabels(), rotation=0, fontsize=12)
s.set_xticklabels(s.get_xticklabels(), rotation=90, fontsize=12)
plt.title("Correlation Heat Map")
plt.show()

# %%
plt.figure(figsize=(12,9))
plt.scatter(segment_data.iloc[:,3], segment_data.iloc[:,5])
plt.xlabel("Age")
plt.ylabel("Income")
plt.title("Scatter plot between Age and Income")
# Out:
# Text(0.5, 1.0, 'Scatter plot between Age and Income')

# %%
scalar=StandardScaler()
scaled_segment=scalar.fit_transform(segment_data)
scaled_segment
# Out:
# array([[-1.731185  , -0.91739884, -0.99302433, ...,  0.09752361,
#          0.29682303,  1.552326  ],
#        [-1.72945295,  1.09003844,  1.00702467, ...,  0.78265438,
#          0.29682303,  1.552326  ],
#        [-1.7277209 , -0.91739884, -0.99302433, ..., -0.83320224,
#         -1.26952539, -0.90972951],
#        ...,
#        [ 1.7277209 , -0.91739884, -0.99302433, ..., -0.90695688,
#         -1.26952539, -0.90972951],
#        [ 1.72945295,  1.09003844,  1.00702467, ..., -0.60332923,
#         -1.26952539, -0.90972951],
#        [ 1.731185  , -0.91739884, -0.99302433, ..., -1.3789866 ,
#         -1.26952539, -0.90972951]])

# %%
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(scaled_segment)
    wcss.append(kmeans.inertia_)
wcss
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [16000.0,
#  12066.146078039474,
#  10195.669345598919,
#  8805.254481669766,
#  7871.96298443615,
#  7279.652806264399,
#  6739.63983588173,
#  6239.019877699335,
#  5925.062962292425,
#  5605.56117200798]

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1,11), wcss, marker=0, linestyle= '--')
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.title("K Means clustering")
plt.show()
#Using Elbow method, the point till which the line is steep and from which the line is flat is choosen as number of clusters. Here it is 4.

# %%
#Now let's fit K-means clustering with 4 clusters
kmeans=KMeans(n_clusters=4, init="k-means++", random_state=42)
kmeans.fit(scaled_segment)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=42)

# %%
scaled_segment
# Out:
# array([[-1.731185  , -0.91739884, -0.99302433, ...,  0.09752361,
#          0.29682303,  1.552326  ],
#        [-1.72945295,  1.09003844,  1.00702467, ...,  0.78265438,
#          0.29682303,  1.552326  ],
#        [-1.7277209 , -0.91739884, -0.99302433, ..., -0.83320224,
#         -1.26952539, -0.90972951],
#        ...,
#        [ 1.7277209 , -0.91739884, -0.99302433, ..., -0.90695688,
#         -1.26952539, -0.90972951],
#        [ 1.72945295,  1.09003844,  1.00702467, ..., -0.60332923,
#         -1.26952539, -0.90972951],
#        [ 1.731185  , -0.91739884, -0.99302433, ..., -1.3789866 ,
#         -1.26952539, -0.90972951]])

# %%
kmeans.labels_
# Out:
# array([3, 0, 2, ..., 2, 0, 2], dtype=int32)

# %%
segmented_kmeans=segment_data.copy()
segmented_kmeans["Segments"]=kmeans.labels_
segmented_kmeans
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size  Segments
# 0                   2         3
# 1                   2         0
# 2                   0         2
# 3                   1         1
# 4                   1         1
# ...               ...       ...
# 1995                0         2
# 1996                0         0
# 1997                0         2
# 1998                0         0
# 1999                0         2
#
# [2000 rows x 9 columns]

# %%
segment_analysis=segmented_kmeans.groupby(["Segments"]).mean()
segment_analysis
# Out:
#                     ID       Sex  Marital status        Age  Education  \
# Segments
# 0         1.000011e+08  0.876289        0.998527  29.002946   1.067747
# 1         1.000007e+08  0.030063        0.178797  35.632911   0.737342
# 2         1.000014e+08  0.403341        0.042959  34.689737   0.742243
# 3         1.000009e+08  0.485185        0.681481  55.814815   2.125926
#
#                  Income  Occupation  Settlement size
# Segments
# 0         105597.536082    0.630339         0.418262
# 1         139944.602848    1.250000         1.387658
# 2          94407.322196    0.255370         0.059666
# 3         156320.200000    1.096296         1.081481

# %%
segment_analysis["Num of Obs"]=segmented_kmeans[["Segments", "Sex"]].groupby(["Segments"]).count()
segment_analysis
# Out:
#                     ID       Sex  Marital status        Age  Education  \
# Segments
# 0         1.000011e+08  0.876289        0.998527  29.002946   1.067747
# 1         1.000007e+08  0.030063        0.178797  35.632911   0.737342
# 2         1.000014e+08  0.403341        0.042959  34.689737   0.742243
# 3         1.000009e+08  0.485185        0.681481  55.814815   2.125926
#
#                  Income  Occupation  Settlement size  Num of Obs
# Segments
# 0         105597.536082    0.630339         0.418262         679
# 1         139944.602848    1.250000         1.387658         632
# 2          94407.322196    0.255370         0.059666         419
# 3         156320.200000    1.096296         1.081481         270

# %%
segment_analysis.rename({0:"standard", 1:"career focussed", 2:"fewer oppurtunities", 3:"well-off"})
# Out:
#                                ID       Sex  Marital status        Age  \
# Segments
# standard             1.000011e+08  0.876289        0.998527  29.002946
# career focussed      1.000007e+08  0.030063        0.178797  35.632911
# fewer oppurtunities  1.000014e+08  0.403341        0.042959  34.689737
# well-off             1.000009e+08  0.485185        0.681481  55.814815
#
#                      Education         Income  Occupation  Settlement size  \
# Segments
# standard              1.067747  105597.536082    0.630339         0.418262
# career focussed       0.737342  139944.602848    1.250000         1.387658
# fewer oppurtunities   0.742243   94407.322196    0.255370         0.059666
# well-off              2.125926  156320.200000    1.096296         1.081481
#
#                      Num of Obs
# Segments
# standard                    679
# career focussed             632
# fewer oppurtunities         419
# well-off                    270

# %%
segmented_kmeans['Labels']=segmented_kmeans['Segments'].map({0:"standard", 1:"career focussed", 2:"fewer oppurtunities", 3:"well-off"})
segmented_kmeans
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size  Segments               Labels
# 0                   2         3             well-off
# 1                   2         0             standard
# 2                   0         2  fewer oppurtunities
# 3                   1         1      career focussed
# 4                   1         1      career focussed
# ...               ...       ...                  ...
# 1995                0         2  fewer oppurtunities
# 1996                0         0             standard
# 1997                0         2  fewer oppurtunities
# 1998                0         0             standard
# 1999                0         2  fewer oppurtunities
#
# [2000 rows x 10 columns]

# %%
plt.figure(figsize=(10,8))
xaxis=segmented_kmeans['Age']
yaxis=segmented_kmeans['Income']
#plt.scatter(segmented_kmeans['Age'],segmented_kmeans['Income'])
sns.scatterplot(data=segmented_kmeans, x='Age',y='Income', hue=segmented_kmeans['Labels'], palette=['g','r','c','m'])
plt.title("Scatterplot on Age and Income showing various segments")
plt.show()

# %%
pca= PCA()
pca.fit(scaled_segment)
#The below code shows how much variance is explained by each component
pca.explained_variance_ratio_
# Out:
# array([0.34103573, 0.23178599, 0.16650585, 0.09955452, 0.06169548,
#        0.04785186, 0.03407515, 0.01749541])

# %%
plt.figure(figsize=(12,9))
plt.plot(range(1,9), pca.explained_variance_ratio_.cumsum(), marker='o', linestyle="--" )
plt.title("Explained variance by Components")
plt.xlabel("Number of components")
plt.ylabel("Cumulative Explained variance")
# Out:
# Text(0, 0.5, 'Cumulative Explained variance')

# %%
pca=PCA(n_components=3)
pca.fit(scaled_segment)
# Out:
# PCA(n_components=3)

# %%
pca.components_ #components show correlation of each variable to the component
df_pca_components=pd.DataFrame(data=pca.components_, columns=segment_data.columns.values, index=['Component 1', 'Component 2', 'Component 3'])
df_pca_components
# Out:
#                    ID       Sex  Marital status       Age  Education  \
# Component 1 -0.345410 -0.328586       -0.187269  0.270283   0.104515
# Component 2  0.107237  0.421320        0.472083  0.355260   0.652786
# Component 3  0.143522 -0.317959       -0.485433  0.613442   0.252258
#
#                Income  Occupation  Settlement size
# Component 1  0.483844    0.461681         0.454337
# Component 2  0.176284    0.061362        -0.030777
# Component 3 -0.123601   -0.344566        -0.262126

# %%
sns.heatmap(df_pca_components, vmin=-1, vmax=1, annot=True, cmap='RdBu')
plt.yticks([0,1,2], ['Component 1', 'Component 2', 'Component 3'], rotation=45, fontsize=9)
# Out:
# ([<matplotlib.axis.YTick at 0x7fda34ce92b0>,
#   <matplotlib.axis.YTick at 0x7fda351c73a0>,
#   <matplotlib.axis.YTick at 0x7fda351eec70>],
#  [Text(0, 0, 'Component 1'),
#   Text(0, 1, 'Component 2'),
#   Text(0, 2, 'Component 3')])

# %%
scores_pca=pca.transform(scaled_segment)
scores_pca
# Out:
# array([[ 2.85978214,  0.93667597,  2.03658632],
#        [ 0.94413038,  0.39449213, -2.43378502],
#        [-0.02303213, -0.8817974 ,  1.97408269],
#        ...,
#        [-1.84179778, -2.15868138,  1.1160118 ],
#        [-2.71683211,  0.56139001, -0.4762533 ],
#        [-2.2097949 , -2.42344957,  0.86070907]])

# %%
wcss=[]
for i in range(1,11):
    kmeans_pca=KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans_pca.fit(scores_pca)
    wcss.append(kmeans_pca.inertia_)
wcss
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [11829.241204508346,
#  7923.329847537421,
#  6076.8177536043295,
#  4702.221015357869,
#  3877.9872007525014,
#  3395.9215861230396,
#  2913.4473200736375,
#  2624.6556886236112,
#  2352.5703891484527,
#  2071.90703864479]

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1,11), wcss, marker=0, linestyle= '--')
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.title("K Means clustering after PCA")
plt.show()
#Using Elbow method, the point till which the line is steep and from which the line is flat is choosen as number of clusters. Here it is 4.

# %%
kmeans_pca= KMeans(n_clusters=4, init="k-means++", random_state=42)
kmeans_pca.fit(scores_pca)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=42)

# %%
wcss1=[]
for i in range(1,11):
    kmeans1_pca=KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans1_pca.fit(scores_pca)
    wcss1.append(kmeans1_pca.inertia_)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
wcss1
# Out:
# [11829.24120450835,
#  7923.3298475374195,
#  6076.817753604326,
#  4702.221015357869,
#  3877.9872007525023,
#  3395.9215861230387,
#  2913.4473200736384,
#  2624.6556886236112,
#  2352.5703891484527,
#  2071.9070386447906]

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1,11), wcss1, marker=0, linestyle= '--')
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.title("K Means clustering after PCA")
plt.show()

# %%
kmeans_pca=KMeans(n_clusters=4, init='k-means++', random_state=42)

# %%
kmeans_pca.fit(scores_pca)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=42)

# %%
segment_pca_kmeans=pd.concat([segment_data.reset_index(drop=True), pd.DataFrame(scores_pca)], axis=1)
segment_pca_kmeans.columns.values[-3:]=['Component 1', 'Component 2', 'Component 3']
segment_pca_kmeans['Segmented k-means after PCA']=kmeans_pca.labels_
segment_pca_kmeans
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size  Component 1  Component 2  Component 3  \
# 0                   2     2.859782     0.936676     2.036586
# 1                   2     0.944130     0.394492    -2.433785
# 2                   0    -0.023032    -0.881797     1.974083
# 3                   1     2.212422    -0.563616     0.635332
# 4                   1     2.110202    -0.425124     1.127543
# ...               ...          ...          ...          ...
# 1995                0    -1.485348     0.432286     1.615196
# 1996                0    -1.672129     0.839600    -0.923547
# 1997                0    -1.841798    -2.158681     1.116012
# 1998                0    -2.716832     0.561390    -0.476253
# 1999                0    -2.209795    -2.423450     0.860709
#
#       Segmented k-means after PCA
# 0                               1
# 1                               2
# 2                               3
# 3                               2
# 4                               2
# ...                           ...
# 1995                            3
# 1996                            0
# 1997                            3
# 1998                            0
# 1999                            3
#
# [2000 rows x 12 columns]

# %%
segment_pca_kmeans_freq=segment_pca_kmeans.groupby(['Segmented k-means after PCA']).mean()
segment_pca_kmeans_freq
# Out:
#                                        ID       Sex  Marital status  \
# Segmented k-means after PCA
# 0                            1.000012e+08  0.919040        0.967016
# 1                            1.000009e+08  0.492537        0.679104
# 2                            1.000007e+08  0.036278        0.194006
# 3                            1.000013e+08  0.338747        0.099768
#
#                                    Age  Education         Income  Occupation  \
# Segmented k-means after PCA
# 0                            28.958021   1.064468  106617.467766    0.659670
# 1                            55.873134   2.130597  156430.727612    1.097015
# 2                            35.466877   0.739748  140435.219243    1.255521
# 3                            34.902552   0.756381   92426.039443    0.211137
#
#                              Settlement size  Component 1  Component 2  \
# Segmented k-means after PCA
# 0                                   0.427286    -1.205155     0.616021
# 1                                   1.082090     1.483593     2.152720
# 2                                   1.394322     1.471999    -0.935925
# 3                                   0.044084    -1.222765    -0.915172
#
#                              Component 3
# Segmented k-means after PCA
# 0                              -0.833262
# 1                               0.893411
# 2                              -0.187509
# 3                               1.009819

# %%
segment_pca_kmeans_freq=segment_pca_kmeans_freq.rename({0:'Standard', 1:'well-off', 2:'career-focussed', 3:'fewer oppurtunities'})
segment_pca_kmeans_freq
# Out:
#                                        ID       Sex  Marital status  \
# Segmented k-means after PCA
# Standard                     1.000012e+08  0.919040        0.967016
# well-off                     1.000009e+08  0.492537        0.679104
# career-focussed              1.000007e+08  0.036278        0.194006
# fewer oppurtunities          1.000013e+08  0.338747        0.099768
#
#                                    Age  Education         Income  Occupation  \
# Segmented k-means after PCA
# Standard                     28.958021   1.064468  106617.467766    0.659670
# well-off                     55.873134   2.130597  156430.727612    1.097015
# career-focussed              35.466877   0.739748  140435.219243    1.255521
# fewer oppurtunities          34.902552   0.756381   92426.039443    0.211137
#
#                              Settlement size  Component 1  Component 2  \
# Segmented k-means after PCA
# Standard                            0.427286    -1.205155     0.616021
# well-off                            1.082090     1.483593     2.152720
# career-focussed                     1.394322     1.471999    -0.935925
# fewer oppurtunities                 0.044084    -1.222765    -0.915172
#
#                              Component 3
# Segmented k-means after PCA
# Standard                       -0.833262
# well-off                        0.893411
# career-focussed                -0.187509
# fewer oppurtunities             1.009819

# %%
segment_pca_kmeans['Legend']=segment_pca_kmeans['Segmented k-means after PCA'].map({0:'Standard', 1:'well-off', 2:'career-focussed', 3:'fewer oppurtunities'})
segment_pca_kmeans
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size  Component 1  Component 2  Component 3  \
# 0                   2     2.859782     0.936676     2.036586
# 1                   2     0.944130     0.394492    -2.433785
# 2                   0    -0.023032    -0.881797     1.974083
# 3                   1     2.212422    -0.563616     0.635332
# 4                   1     2.110202    -0.425124     1.127543
# ...               ...          ...          ...          ...
# 1995                0    -1.485348     0.432286     1.615196
# 1996                0    -1.672129     0.839600    -0.923547
# 1997                0    -1.841798    -2.158681     1.116012
# 1998                0    -2.716832     0.561390    -0.476253
# 1999                0    -2.209795    -2.423450     0.860709
#
#       Segmented k-means after PCA               Legend
# 0                               1             well-off
# 1                               2      career-focussed
# 2                               3  fewer oppurtunities
# 3                               2      career-focussed
# 4                               2      career-focussed
# ...                           ...                  ...
# 1995                            3  fewer oppurtunities
# 1996                            0             Standard
# 1997                            3  fewer oppurtunities
# 1998                            0             Standard
# 1999                            3  fewer oppurtunities
#
# [2000 rows x 13 columns]

# %%
xaxis=segment_pca_kmeans['Component 1']
yaxis=segment_pca_kmeans['Component 2']
plt.figure(figsize=(10,8))
sns.scatterplot(data=segment_pca_kmeans, x='Component 1', y='Component 2', hue=segment_pca_kmeans['Legend'], palette=['g','r','c','m'])
plt.title("Segmented clusters after PCA")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=segment_pca_kmeans, x='Component 1', y='Component 3', hue=segment_pca_kmeans['Legend'], palette=['g','r','c','m'])
plt.title("Segmented clusters after PCA")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=segment_pca_kmeans, x='Component 2', y='Component 3', hue=segment_pca_kmeans['Legend'], palette=['g','r','c','m'])
plt.title("Segmented clusters after PCA")
plt.show()

# %%
pickle.dump(scalar, open('scaler.pickle', 'wb'))
pickle.dump(pca, open('pca.pickle', 'wb'))
pickle.dump(kmeans_pca, open('kmeans_pca.pickle', 'wb'))

# %%
kmeans_pca
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
scalar
# Out:
# StandardScaler()

# %%
pca
# Out:
# PCA(n_components=3)
